# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/cars_engage_2022.csv'
car_data = pd.read_csv(path)

# %%
car_data
# Out:
#       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
car_data['Cylinders'].isnull().sum()
# Out:
# 0

# %%
car_data['Cylinders'] = car_data['Cylinders'].fillna(car_data.Cylinders.mode()[0])
car_data['Cylinders'].isnull().sum()
# Out:
# 0

# %%
car_data["Make"].fillna("Unknown", inplace=False)

car_data["Displacement"]=pd.to_numeric(car_data["Displacement"],errors='coerce')
car_data["Displacement"].fillna(car_data["Displacement"].mean(),inplace=False)
car_data["Cylinders"].fillna(car_data["Cylinders"].mean(),inplace=False)
car_data["Valves_Per_Cylinder"].fillna(car_data["Valves_Per_Cylinder"].mean(),inplace=False)
car_data["Drivetrain"].fillna("Unknown", inplace=False)
car_data["Cylinder_Configuration"].fillna("Unknown", inplace=False)
car_data["Emission_Norm"].fillna("Unknown", inplace=False)
car_data["Engine_Location"].fillna("Unknown", inplace=False)
car_data["Fuel_System"].fillna("Unknown", inplace=False)

car_data["Fuel_Tank_Capacity"]=pd.to_numeric(car_data["Fuel_Tank_Capacity"],errors='coerce')
car_data["Fuel_Tank_Capacity"].fillna(car_data["Fuel_Tank_Capacity"].mean(),inplace=False)

car_data["Height"]=pd.to_numeric(car_data["Height"],errors='coerce')
car_data["Height"].fillna(car_data["Height"].mean(),inplace=False)

car_data["Width"]=pd.to_numeric(car_data["Width"],errors='coerce')
car_data["Width"].fillna(car_data["Width"].mean(),inplace=False)
car_data["Body_Type"].fillna("Unknown", inplace=False)
car_data["Doors"].fillna(car_data["Doors"].mean(),inplace=False)
car_data["City_Mileage"]=pd.to_numeric(car_data["City_Mileage"],errors='coerce')
car_data["City_Mileage"].fillna(car_data["City_Mileage"].mean(),inplace=False)

car_data["Highway_Mileage"]=pd.to_numeric(car_data["Highway_Mileage"],errors='coerce')
car_data["Highway_Mileage"].fillna(car_data["Highway_Mileage"].mean(),inplace=False)

car_data["ARAI_Certified_Mileage"]=pd.to_numeric(car_data["ARAI_Certified_Mileage"],errors='coerce')
car_data["ARAI_Certified_Mileage"].fillna(car_data["ARAI_Certified_Mileage"].mean(),inplace=False)
car_data["ARAI_Certified_Mileage_for_CNG"].fillna((car_data["ARAI_Certified_Mileage_for_CNG"].str.rstrip("km/kg").astype(float)).mean(),inplace=False)

car_data["Kerb_Weight"]=pd.to_numeric(car_data["Kerb_Weight"],errors='coerce')
car_data["Kerb_Weight"].fillna(car_data["Kerb_Weight"].mean(),inplace=False)
car_data["Gears"]=pd.to_numeric(car_data["Gears"],errors='coerce')
car_data["Gears"].fillna(car_data["Gears"].mean(),inplace=False)
car_data["Ground_Clearance"].fillna((car_data["Ground_Clearance"].str.rstrip("mm").astype(float)).mean(),inplace=False)
car_data["Front_Brakes"].fillna("Front_Brakes", inplace=False)
car_data["Rear_Brakes"].fillna("Rear_Brakes", inplace=False)
car_data["Front_Suspension"].fillna("Front_Suspension", inplace=False)
car_data["Rear_Suspension"].fillna("Rear_Suspension", inplace=False)

car_data["Front_Track"]=pd.to_numeric(car_data["Front_Track"],errors='coerce')
car_data["Front_Track"].fillna(car_data["Front_Track"].mean(),inplace=False)

car_data["Rear_Track"]=pd.to_numeric(car_data["Rear_Track"],errors='coerce')
car_data["Rear_Track"].fillna(car_data["Rear_Track"].mean(),inplace=False)
car_data["Front_Tyre_&_Rim"].fillna("Unknown", inplace=False)
car_data["Rear_Tyre_&_Rim"].fillna("Unknown", inplace=False)
car_data["Power_Steering"].fillna("Unknown", inplace=False)
car_data["Power_Windows"].fillna("Unknown", inplace=False)
car_data["Power_Seats"].fillna("Unknown", inplace=False)
car_data["Keyless_Entry"].fillna("Unknown", inplace=False)
car_data["Torque"].fillna("Unknown", inplace=False)
car_data["Odometer"].fillna("Unknown", inplace=False)
car_data["Speedometer"].fillna("Unknown", inplace=False)
car_data["Tachometer"].fillna("Unknown", inplace=False)
car_data["Tripmeter"].fillna("Unknown", inplace=False)
car_data["Seating_Capacity"]=pd.to_numeric(car_data["Seating_Capacity"],errors='coerce')
car_data["Seating_Capacity"].fillna(car_data["Seating_Capacity"].mean(),inplace=False)
car_data["Seats_Material"].fillna("Unknown", inplace=False)
car_data["Type"].fillna("Unknown", inplace=False)
car_data["Wheelbase"].fillna("Unknown", inplace=False)
car_data["Wheels_Size"].fillna("Unknown", inplace=False)
car_data["Start_/_Stop_Button"].fillna("Unknown", inplace=False)
car_data["12v_Power_Outlet"].fillna("Unknown", inplace=False)
car_data["Audiosystem"].fillna("Unknown", inplace=False)
car_data["Aux-in_Compatibility"].fillna("Unknown", inplace=False)
car_data["Average_Fuel_Consumption"].fillna("Unknown", inplace=False)
car_data["Basic_Warranty"].fillna("Unknown", inplace=False)
car_data["Bluetooth"].fillna("Unknown", inplace=False)
car_data["Boot-lid_Opener"].fillna("Unknown", inplace=False)

car_data["Boot_Space"]=pd.to_numeric(car_data["Boot_Space"],errors='coerce')
car_data["Boot_Space"].fillna(car_data["Boot_Space"].mean(),inplace=False)
car_data["CD_/_MP3_/_DVD_Player"].fillna("Unknown", inplace=False)
car_data["Central_Locking"].fillna("Unknown", inplace=False)
car_data["Child_Safety_Locks"].fillna("Unknown", inplace=False)
car_data["Clock"].fillna("Unknown", inplace=False)
car_data["Cup_Holders"].fillna("Unknown", inplace=False)
car_data["Distance_to_Empty"].fillna("Unknown", inplace=False)
car_data["Door_Pockets"].fillna("Unknown", inplace=False)
car_data["Engine_Malfunction_Light"].fillna("Unknown", inplace=False)
car_data["Extended_Warranty"].fillna("Unknown", inplace=False)
car_data["FM_Radio"].fillna("Unknown", inplace=False)
car_data["Fuel-lid_Opener"].fillna("Unknown", inplace=False)
car_data["Fuel_Gauge"].fillna("Unknown", inplace=False)
car_data["Handbrake"].fillna("Unknown", inplace=False)
car_data["Instrument_Console"].fillna("Unknown", inplace=False)
car_data["Low_Fuel_Warning"].fillna("Unknown", inplace=False)

car_data["Minimum_Turning_Radius"]=pd.to_numeric(car_data["Minimum_Turning_Radius"],errors='coerce')
car_data["Minimum_Turning_Radius"].fillna(car_data["Minimum_Turning_Radius"].mean(),inplace=False)
car_data["Multifunction_Display"].fillna("Unknown", inplace=False)
car_data["Sun_Visor"].fillna("Unknown", inplace=False)
car_data["Third_Row_AC_Vents"].fillna("Unknown", inplace=False)
car_data["Ventilation_System"].fillna("Unknown", inplace=False)
car_data["Auto-Dimming_Rear-View_Mirror"].fillna("Unknown", inplace=False)
car_data["Hill_Assist"].fillna("Unknown", inplace=False)
car_data["Gear_Indicator"].fillna("Unknown", inplace=False)
car_data["3_Point_Seat-Belt_in_Middle_Rear_Seat"].fillna("Unknown", inplace=False)
car_data["Ambient_Lightning"].fillna("Unknown", inplace=False)
car_data["Cargo/Boot_Lights"].fillna("Unknown", inplace=False)
car_data["Drive_Modes"].fillna("Unknown", inplace=False)
car_data["Engine_Immobilizer"].fillna("Unknown", inplace=False)
car_data["High_Speed_Alert_System"].fillna("Unknown", inplace=False)
car_data["Lane_Watch_Camera/_Side_Mirror_Camera"].fillna("Unknown", inplace=False)
car_data["Passenger_Side_Seat-Belt_Reminder"].fillna("Unknown", inplace=False)
car_data["Seat_Back_Pockets"].fillna("Unknown", inplace=False)
car_data["Voice_Recognition"].fillna("Unknown", inplace=False)
car_data["Walk_Away_Auto_Car_Lock"].fillna("Unknown", inplace=False)
car_data["ABS_(Anti-lock_Braking_System)"].fillna("Unknown", inplace=False)
car_data["Headlight_Reminder"].fillna("Unknown", inplace=False)
car_data["Adjustable_Headrests"].fillna("Unknown", inplace=False)

car_data["Gross_Vehicle_Weight"]=pd.to_numeric(car_data["Gross_Vehicle_Weight"],errors='coerce')
car_data["Gross_Vehicle_Weight"].fillna(car_data["Gross_Vehicle_Weight"].mean(),inplace=False)
car_data["Airbags"].fillna("Unknown", inplace=False)
car_data["Door_Ajar_Warning"].fillna("Unknown", inplace=False)
car_data["EBD_(Electronic_Brake-force_Distribution)"].fillna("Unknown", inplace=False)
car_data["Fasten_Seat_Belt_Warning"].fillna("Unknown", inplace=False)
car_data["Gear_Shift_Reminder"].fillna("Unknown", inplace=False)
car_data["Number_of_Airbags"]=pd.to_numeric(car_data["Number_of_Airbags"],errors='coerce')
car_data["Number_of_Airbags"].fillna(car_data["Number_of_Airbags"].mean(),inplace=False)
car_data["Compression_Ratio"]=pd.to_numeric(car_data["Compression_Ratio"],errors='coerce')
car_data["Compression_Ratio"].fillna(car_data["Compression_Ratio"].mean(),inplace=False)
car_data["Adjustable_Steering_Column"].fillna("Unknown", inplace=False)
car_data["Airbags"].fillna("Unknown", inplace=False)

car_data["Other_Specs"].fillna("Unknown", inplace=False)

car_data["Other_specs"].fillna("Unknown", inplace=False)
car_data["Parking_Assistance"].fillna("Unknown", inplace=False)
car_data["Key_Off_Reminder"].fillna("Unknown", inplace=False)
car_data["USB_Compatibility"].fillna("Unknown", inplace=False)
car_data["Android_Auto"].fillna("Unknown", inplace=False)
car_data["Apple_CarPlay"].fillna("Unknown", inplace=False)
car_data["Cigarette_Lighter"].fillna("Unknown", inplace=False)
car_data["Infotainment_Screen"].fillna("Unknown", inplace=False)
car_data["Multifunction_Steering_Wheel"].fillna("Unknown", inplace=False)
car_data["Average_Speed"].fillna("Unknown", inplace=False)
car_data["EBA_(Electronic_Brake_Assist)"].fillna("Unknown", inplace=False)
car_data["Seat_Height_Adjustment"].fillna("Unknown", inplace=False)
car_data["Navigation_System"].fillna("Unknown", inplace=False)
car_data["Second_Row_AC_Vents"].fillna("Unknown", inplace=False)
car_data["Tyre_Pressure_Monitoring_System"].fillna("Unknown", inplace=False)
car_data["Rear_Center_Armrest"].fillna("Unknown", inplace=False)
car_data["iPod_Compatibility"].fillna("Unknown", inplace=False)
car_data["ESP_(Electronic_Stability_Program)"].fillna("Unknown", inplace=False)
car_data["Cooled_Glove_Box"].fillna("Unknown", inplace=False)
car_data["Recommended_Tyre_Pressure"].fillna("Unknown", inplace=False)
car_data["Heated_Seats"].fillna("Unknown", inplace=False)
car_data["Turbocharger"].fillna("Unknown", inplace=False)
car_data["ISOFIX_(Child-Seat_Mount)"].fillna("Unknown", inplace=False)
car_data["Rain_Sensing_Wipers"].fillna("Unknown", inplace=False)
car_data["Paddle_Shifters"].fillna("Unknown", inplace=False)
car_data["Leather_Wrapped_Steering"].fillna("Unknown", inplace=False)
car_data["Automatic_Headlamps"].fillna("Unknown", inplace=False)
car_data["Engine_Type"].fillna("Unknown", inplace=False)
car_data["ASR_/_Traction_Control"].fillna("Unknown", inplace=False)
car_data["Cruise_Control"].fillna("Unknown", inplace=False)
car_data["USB_Ports"]=pd.to_numeric(car_data["USB_Ports"],errors='coerce')
car_data["USB_Ports"].fillna(car_data["USB_Ports"].mean(),inplace=False)
car_data["Heads-Up_Display"].fillna("Unknown", inplace=False)
car_data["Welcome_Lights"].fillna("Unknown", inplace=False)
car_data["Battery"].fillna("Unknown", inplace=False)
car_data["Electric_Range"]=pd.to_numeric(car_data["Electric_Range"],errors='coerce')
car_data["Electric_Range"].fillna(car_data["Electric_Range"].mean(),inplace=False)
# Out:
# 0       195.17
# 1       195.17
# 2       195.17
# 3       195.17
# 4       195.17
#          ...
# 1271    195.17
# 1272    195.17
# 1273    195.17
# 1274    195.17
# 1275    195.17
# Name: Electric_Range, Length: 1276, dtype: float64

# %%
car_data['Displacement']=car_data['Displacement'].fillna(car_data['Displacement'].mean())
car_data['Cylinders']=car_data['Cylinders'].fillna(car_data['Cylinders'].median())
car_data['Cylinders']=car_data['Cylinders'].fillna(car_data['Cylinders'].median())
car_data['Valves_Per_Cylinder']=car_data['Valves_Per_Cylinder'].fillna(car_data['Valves_Per_Cylinder'].mean())
car_data['Fuel_Tank_Capacity']=car_data['Fuel_Tank_Capacity'].fillna(car_data['Fuel_Tank_Capacity'].mean())
car_data['Height']=car_data['Height'].fillna(car_data['Height'].mean())

car_data['Width']=car_data['Width'].fillna(car_data['Width'].mean())
car_data['Doors']=car_data['Doors'].fillna(car_data['Doors'].median())
car_data['City_Mileage']=car_data['City_Mileage'].fillna(car_data['City_Mileage'].mean())
car_data['Highway_Mileage']=car_data['Highway_Mileage'].fillna(car_data['Highway_Mileage'].mean())
car_data['ARAI_Certified_Mileage']=car_data['ARAI_Certified_Mileage'].fillna(car_data['ARAI_Certified_Mileage'].mean())

car_data['Kerb_Weight']=car_data['Kerb_Weight'].fillna(car_data['Kerb_Weight'].mean())
car_data['Gears']=car_data['Gears'].fillna(car_data['Gears'].mean())

car_data['Front_Track']=car_data['Front_Track'].fillna(car_data['Front_Track'].mean())
car_data['Rear_Track']=car_data['Rear_Track'].fillna(car_data['Rear_Track'].mean())
car_data['Seating_Capacity']=car_data['Seating_Capacity'].fillna(car_data['Seating_Capacity'].median())

car_data['Boot_Space']=car_data['Boot_Space'].fillna(car_data['Boot_Space'].mean())
car_data['Minimum_Turning_Radius']=car_data['Minimum_Turning_Radius'].fillna(car_data['Minimum_Turning_Radius'].mean())
car_data['Gross_Vehicle_Weight']=car_data['Gross_Vehicle_Weight'].fillna(car_data['Gross_Vehicle_Weight'].mean())
car_data['Number_of_Airbags']=car_data['Number_of_Airbags'].fillna(car_data['Number_of_Airbags'].median())
car_data['Compression_Ratio']=car_data['Compression_Ratio'].fillna(car_data['Compression_Ratio'].mean())
car_data['USB_Ports']=car_data['USB_Ports'].fillna(car_data['USB_Ports'].mean())

# %%
car_data
# Out:
#       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
#       Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...
